# %% [markdown]
# <a href="https://colab.research.google.com/github/hnhyhj/Python-study/blob/master/5_Simple_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 5
# # Simple Functions

# %% [markdown]
# ![istock-851580382.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![屏幕快照 2020-11-25 11.57.59.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.1.1 Function Name

# %% [markdown]
# Each function has a name. Like a variable name, a function name may consist of letters,
# digits, and underscores, and cannot start with a digit. Almost all standard Python functions
# consist only of lower case letters. Usually a function name expresses concisely what the
# function does.
# When referring to a function, it is convention to use the name, and put an opening and
# closing parenthesis after the name, as functions are always called in code with such parentheses.

# %% [markdown]
# ### 5.1.2 Parameters

# %% [markdown]
# Some functions are called with parameters (“arguments”), which may or may not be
# mandatory. The parameters are placed between the parentheses that follow the function
# name. If there are multiple parameters, you place commas between them.

# %%
x = 1.56
print( int( x ) )
print( x )
# Out:
# 1
# 1.56

# %%
base = 2
exponent = 3
print( pow( base , exponent ) )
# Out:
# 8

# %% [markdown]
# <font size=5>!!!Caution</font>

# %%
x = pow( 3, "2" )
y = int( "two-and-a-half" )

# %% [markdown]
# ### 5.1.3 Return value

# %% [markdown]
# A function may or may not “return” a value. If a function returns a value, that value can be
# used in your code.

# %%
x = 2.1
y = ' 3 '
z = int( x )
print( z )
print( int( y ) )
# Out:
# 2
# 3

# %% [markdown]
# Not all functions return a value. For instance, the print() function does not. If you are not
# careful, this may lead to strange behavior of your program.

# %%
print( print( "Hello , world!" ) )
# Out:
# Hello , world!
# None

# %% [markdown]
# ## 5.2 Some basic functions

# %% [markdown]
# ### 5.2.1 Type casting
# ![屏幕快照 2020-11-25 12.02.04.png](data:image/png;base64,...)

# %%
print(10 * int("100,000,000"))

# %% [markdown]
# ### 5.2.2 Calculations

# %%
x = -2
y = 3
z = 1.27
print( abs( x ) )
print( max( x, y, z ) )
print( min( x, y, z ) )
print( pow( x, y ) )
print( round( z, 1 ) )
# Out:
# 2
# 3
# -2
# -8
# 1.3

# %% [markdown]
# ### 5.2.3 len( )

# %% [markdown]
# **len( )** is a basic function that gets one parameter, and it returns the length of that parameter.
# For now, the only data type which you will use **len( )** for is the string. **len( )** returns the
# length of the string, i.e., the number of characters.

# %%
print(len( ' can ' ))
print(len('cannot'))
print(len("")) # "" is an empty string

# %%
# And what about the code below? Think carefully, then check the result.
print(len('can\'t'))

# %% [markdown]
# ### 5.2.4 input( )
# <font size=4>###You will use input function in every CCC contest.###</font>

# %%
text = input( "Please enter some text: " )
print( "You entered:", text )

# %% [markdown]
# <font size=5>!!!Be aware that input( ) always returns a string.!!! </font>

# %%
number = input( "Please enter a number: " )
print( "Your number squared is", number * number )

# %% [markdown]
# ### 5.2.5 print( )
# <font size=4>###You will also use output function in every CCC contest.###</font>

# %% [markdown]
# The function **print( )** takes zero or more parameters, displays them (if there are multiple,
# with a separating space in between each pair of them), and then “goes to the next line” (i.e.,
# if you use two **print( )** statements, the second one will display its parameters below what
# the first one displays).

# %% [markdown]
# **print( )** can get two special parameters, called sep and end.
# - sep indicates what should be printed between each of the parameters, and by default is a
# space. You can use sep to turn the separating space into anything else, including an empty
# string.
# - end indicates what **print( )** should put after all the parameters have been displayed, and
# by default is a “newline.” You can use end to change what **print( )** does after displaying
# the parameters, for instance, you can ensure that **print( )** does not “go to the next line.”

# %%
print( "X", "X", "X", sep="x" )
print( "X", end="" )
print( "Y", end="" )
print( "Z" )
# Out:
# XxXxX
# XYZ

# %% [markdown]
# ### 5.2.6 format( )

# %% [markdown]
# **format( )** represents a rather complex functionality that is employed in a particular way.
# It allows you to create a formatted string, i.e., a string in which certain values appear in a
# specific format.

# %% [markdown]
# the **format( )** will return a new string, which is a
# formatted version of the string for which it is called. It can take any number of parameters,
# and in the process of formatting, will insert these parameter values in particular places in
# the resulting string.

# %%
print( 7/11 )
# Out:
# 0.6363636363636364

# %%
print( round( 7/11, 3 ) )
# Out:
# 0.636

# %%
print( "{:.5f}".format( 7/11 ) )
# Out:
# 0.63636

# %%
print( "The first 3 numbers are {}, {} and {}.".format("one", "two", "three" ) )
# Out:
# The first 3 numbers are one, two and three.

# %%
print( "Backwards they are {2}, {1} and {0}.".format("one", "two", "three" ) )
# Out:
# Backwards they are three, two and one.

# %%
print( "The first 3 numbers are {}, {} and {}.".format("one", 2, 3.0 ) )
# Out:
# The first 3 numbers are one, 2 and 3.0.

# %%
print( "The first 3 numbers are {:7}, {:7} and {:7}.".format("one", "two", "three" ) )
# Out:
# The first 3 numbers are one    , two     and three  .

# %%
print( "The first 3 numbers are {:4}, {:4} and {:4}.".format("one", "two", "three" ) )
# Out:
# The first 3 numbers are one , two  and three.

# %%
print( "The first 3 numbers are {:>7}, {:^7} and {:<7}.".format("one", "two", "three" ) )
# Out:
# The first 3 numbers are     one,   two   and three  .

# %%
print( "{} divided by {} is {}".format( 1, 2, 1/2 ) )
print( "{:d} divided by {:d} is {:f}".format( 1, 2, 1/2 ) )
print( "{:f} divided by {:f} is {:f}".format( 1, 2, 1/2 ) )
# Out:
# 1 divided by 2 is 0.5
# 1 divided by 2 is 0.500000
# 1.000000 divided by 2.000000 is 0.500000

# %%
print( "{:5d} divided by {:5d} is {:5f}".format( 1, 2, 1/2 ) )
print( "{:<5f} divided by {:^5f} is {:>5f}".format( 1, 2, 1/2 ) )
# Out:
#     1 divided by     2 is 0.500000
# 1.000000 divided by 2.000000 is 0.500000

# %%
print( "{:.2f} divided by {:.2f} is {:.2f}".format( 1, 2, 1/2 ) )
# Out:
# 1.00 divided by 2.00 is 0.50

# %%
s = "{:>5d} times {:>5.2f} is {:>5.2f}"
print( s.format( 1, 3.75, 1 * 3.75 ) )
print( s.format( 2, 3.75, 2 * 3.75 ) )
print( s.format( 3, 3.75, 3 * 3.75 ) )
print( s.format( 4, 3.75, 4 * 3.75 ) )
print( s.format( 5, 3.75, 5 * 3.75 ) )
# Out:
#     1 times  3.75 is  3.75
#     2 times  3.75 is  7.50
#     3 times  3.75 is 11.25
#     4 times  3.75 is 15.00
#     5 times  3.75 is 18.75

# %% [markdown]
# ### 5.2.7 f-Strings: A New and Improved Way to Format Strings in Python
#
# The good news is that f-strings are here to save the day. They slice! They dice! They make julienne fries! Okay, they do none of those things, but they do make formatting easier. They joined the party in Python 3.6. You can read all about it in PEP 498, which was written by Eric V. Smith in August of 2015.

# %%
name = "Eric"
age = 74
f"Hello, {name}. You are {age}."
# Out:
# 'Hello, Eric. You are 74.'

# %% [markdown]
# [Python 3's f-Strings: An Improved String Formatting Syntax (Guide)](https://realpython.com/python-f-strings/)

# %% [markdown]
# ## 5.3 Modules
# Python offers some basic functions, some of which are introduced above. Besides those,
# Python offers a large assortment of so-called “modules,” which contain many more useful
# functions. To use functions from a module in your program, you have to import the module, by writing a line “**import \<modulename>**” at the top of your code.

# %% [markdown]
# ### 5.3.1 math
# ![屏幕快照 2020-11-26 12.07.42.png](data:image/png;base64,...)

# %%
import math
print( math.sqrt( 4 ) )

# %%
from math import sqrt as squareroot
print( squareroot( 4 ) )

# %% [markdown]
# ### 5.3.2 random
#
# The **random** module contains functions that return pseudo-random numbers. I say
# “pseudo-random” and not “random,” because it is impossible for digital computers to
# generate actual random numbers. However, for all intents and purposes you may assume
# that the functions in the random module cough up random values.

# %% [markdown]
# ![屏幕快照 2020-11-26 12.09.31.png](data:image/png;base64,...)

# %% [markdown]
# ![屏幕快照 2020-11-26 12.09.38.png](data:image/png;base64,...)

# %%
from random import random , randint , seed
seed()
print( "A random number between 1 and 10 is", randint( 1, 10 ) )
print( "Another is", randint( 1, 10 ) )
seed( 0 )
print( "3 random numbers are:", random(), random(), random() )
seed( 0 )
print( "The same 3 numbers are:", random(), random(), random() )
# Out:
# A random number between 1 and 10 is 3
# Another is 9
# 3 random numbers are: 0.8444218515250481 0.7579544029403025 0.420571580830845
# The same 3 numbers are: 0.8444218515250481 0.7579544029403025 0.420571580830845

# %% [markdown]
# ## [Python built-in functions] (https://docs.python.org/3/library/functions.html#built-in-functions)
#
# ![屏幕快照 2020-11-29 19.02.53.png](data:image/png;base64,...)
