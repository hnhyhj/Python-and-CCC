# %% [markdown]
# <a href="https://colab.research.google.com/github/hnhyhj/Python-study/blob/master/19_Bitewise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 19
# # Bitwise Operators
#
# ---

# %% [markdown]
# ## 1 Bits and bytes
#
# A bit is the smallest size data unit that a computer can handle. A single bit can have only two different values, namely 1 and zero.
#
# ![屏幕快照 2020-11-24 10.21.08.png](data:image/png;base64,...)

# %% [markdown]
# ## 2 Manipulating bits
#
# ![屏幕快照 2020-11-24 10.26.55.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.1 Shfting

# %%
code = "!"

# %%
ord(code)
# Out:
# 33

# %%
bin(ord(code))
# Out:
# '0b100001'

# %%
bin(ord(code)>>1)
# Out:
# '0b10000'

# %%
bin(ord(code)<<1)
# Out:
# '0b1000010'

# %% [markdown]
# ### 2.2 Bitwise and (&)

# %%
print( 11 & 6 )
# Out:
# 2

# %% [markdown]
# ### 2.3 Bitwise or (|)

# %%
print( 11 | 6 )
# Out:
# 15

# %% [markdown]
# ### 2.4 Bitwise not (~)

# %%
print( ~11 )
# Out:
# -12

# %% [markdown]
# ### 2.5 Bitwise xor (^)

# %%
print( 11 ^ 6 )
# Out:
# 13

# %% [markdown]
# ---
#
#
# ### 2.7 Warning: the precedence of bitwise operators is not that they are handled before other operators. Make sure that you use parentheses to order the operators when you use bitwise operators in a calculation.
#
#
# ---

# %%
print( 1<<1 + 2<<1 )
# Out:
# 16

# %%
print( (1<<1) + (2<<1) )
# Out:
# 6
