# %% [markdown]
# <a href="https://colab.research.google.com/github/hnhyhj/Python-study/blob/master/7_Iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 7
# # Iterations
# Computers do not get bored. If you want the computer to repeat a certain task hundreds
# of thousands of times, it does not protest. Humans hate too much repetition. Therefore,
# repetitious tasks should be performed by computers. All programming languages support repetitions. The general class of programming constructs that allow the definition of
# repetitions are called “iterations.” A term which is even more common for such tasks is
# “loops.”

# %% [markdown]
# <font size="5">[Visualization] (http://pythontutor.com/)</font>
# ![屏幕快照 2020-11-25 11.24.11.png](data:image/png;base64,...)

# %% [markdown]
# ## 7.1 while **loop**
# ![屏幕快照 2020-11-25 10.24.45.png](data:image/png;base64,...)

# %%
num = 1
while num <= 5:
  print( num )
  num = num + 1
print( "Done" )
# Out:
# 1
# 2
# 3
# 4
# 5
# Done

# %% [markdown]
# ### 7.1.1 **Endless loops**

# %%
number = 1
total = 0

while True:
  total += number
  print("Total is", total)

# %%
print((number * number) % 1000 != 0)
# Out:
# True

# %% [markdown]
# ## 7.2 for **loop**
# ![屏幕快照 2020-11-25 10.30.54.png](data:image/png;base64,...)

# %%
for letter in "banana":
  print(letter)
print("Done")
# Out:
# b
# a
# n
# a
# n
# a
# Done

# %% [markdown]
# ### 7.2.1 for **loop using a range of numbers**

# %%
for x in range(3, 101, 3):
  print( x )

# %% [markdown]
# ![屏幕快照 2020-11-25 10.36.57.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# [**Range( ) Practices**](https://thepythonguru.com/python-builtin-functions/range/)
#
# ---

# %% [markdown]
# ## 7.3 Loop control statements
# There are three extra statements that help you control the flow in a loop. They are **else**,
# **break**, and continue. They work with both while and for loops.

# %% [markdown]
# ### 7.3.1 else
# Just like with an if statement, you can add an else statement to the end of a while or
# for loop. The code block for the else is executed whenever the loop ends, i.e., when the
# boolean expression for the while loop evaluates to False, or when the last item of the
# collection of the for loop is processed.

# %%
i = 0
while i < 5:
  print(i)
  i += 1
else:
  print("The loop ends , i is now", i)
print("Done")
# Out:
# 0
# 1
# 2
# 3
# 4
# The loop ends , i is now 5
# Done

# %% [markdown]
# ### 7.3.2 break
# The break statement allows you to break out of a loop prematurely.

# %%
i = 1
while i <= 1000000:
  num1 = int( "1" + str( i ) )
  num2 = int( str( i ) + "1" )
  if num2 == 3 * num1:
    print( num2 , "is three times", num1 )
    break
  i = i + 1
else:
  print( "No answer found" )
# Out:
# 428571 is three times 142857

# %% [markdown]
# ### 7.3.3 Continue
# When the continue statement is encountered in the code block of a loop, the current cycle
# ends immediately and the code loops back to the start of the loop. For a while loop, that
# means that the boolean expression is evaluated again. For a for loop, that means that the
# next item is taken from the collection and processed.

# %%
num = 0
while num < 100:
  num += 1
  if num%2 == 0:
    continue
  if num%3 == 0:
    continue
  if num%10 == 7:
    continue
  if num%10 == 9:
    continue
  print( num )
# Out:
# 1
# 5
# 11
# 13
# 23
# 25
# 31
# 35
# 41
# 43
# 53
# 55
# 61
# 65
# 71
# 73
# 83
# 85
# 91
# 95

# %% [markdown]
# ![屏幕快照 2020-11-25 11.05.21.png](data:image/png;base64,...)

# %% [markdown]
# ## 7.4 Nested loops

# %%
for i in range( 3 ):
  print( "Entering the outer loop for i =", i )
  for j in range( 3 ):
    print( " Entering the inner loop for j =", j )
    print( " (i,j) = ({},{})".format( i, j ) )
    print( " Leaving the inner loop for j =", j )
  print( "Leaving the outer loop for i =", i )

# %%
for i in range( 3 ):
  for j in range( 3 ):
    for k in range( 3 ):
      print( "({},{},{})".format( i, j, k ) )

# %% [markdown]
# - You should be aware that when you use a break or continue in an inner loop, it will
# only break out of the inner loop or continue with the inner loop, respectively. There is no
# command that you can give in an inner loop that breaks out of both the inner and outer
# loop immediately.
# - Unless you use them in a function, then you can exit the function at any time and so interrupt both the inner
# and the outer loop.

# %% [markdown]
# ## 7.5  Being smart about loops

# %% [markdown]
# <font size="5">Need it or not?</font>

# %% [markdown]
# Especially soemtime when you are in a CCC contest...

# %% [markdown]
# ## 7.6 A tip
# ![屏幕快照 2020-11-25 11.36.31.png](data:image/png;base64,...)
